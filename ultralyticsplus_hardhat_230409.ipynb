# %% [markdown]
# <a href="https://colab.research.google.com/github/RP-SDAAI/Capstone-Project/blob/main/ultralyticsplus_hardhat_230409.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Install repository to allows IPython to use Google Drive for file management

# %%
#git clone git://github.com/jupyter/jupyter-drive.git
#pip install -e jupyter-drive

# %% [markdown]
# ### To install the notebook extension and activate your configuration with Google Drive

# %%
#python -m jupyterdrive

# %%
pip install --upgrade google-api-python-client google-auth-httplib2 google-auth-oauthlib
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: google-api-python-client in /usr/local/lib/python3.9/dist-packages (2.70.0)
# Collecting google-api-python-client
#   Downloading google_api_python_client-2.84.0-py2.py3-none-any.whl (11.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.2/11.2 MB 57.3 MB/s eta 0:00:00
# Requirement already satisfied: google-auth-httplib2 in /usr/local/lib/python3.9/dist-packages (0.1.0)
# Requirement already satisfied: google-auth-oauthlib in /usr/local/lib/python3.9/dist-packages (1.0.0)
# Requirement already satisfied: httplib2<1dev,>=0.15.0 in /usr/local/lib/python3.9/dist-packages (from google-api-python-client) (0.21.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.9/dist-packages (from google-api-python-client) (4.1.1)
# Requirement already satisfied: google-auth<3.0.0dev,>=1.19.0 in /usr/local/lib/python3.9/dist-packages (from google-api-python-client) (2.17.1)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in /usr/local/lib/python3.9/dist-packages (from google-api-python-client) (2.11.0)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from google-auth-httplib2) (1.16.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from google-auth-oauthlib) (1.3.1)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in /usr/local/lib/python3.9/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (1.59.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5 in /usr/local/lib/python3.9/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (3.20.3)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /usr/local/lib/python3.9/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (2.27.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.9/dist-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.9/dist-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client) (4.9)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.9/dist-packages (from httplib2<1dev,>=0.15.0->google-api-python-client) (3.0.9)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.9/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib) (3.2.2)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.9/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0dev,>=1.19.0->google-api-python-client) (0.4.8)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (2.0.12)
# Installing collected packages: google-api-python-client
#   Attempting uninstall: google-api-python-client
#     Found existing installation: google-api-python-client 2.70.0
#     Uninstalling google-api-python-client-2.70.0:
#       Successfully uninstalled google-api-python-client-2.70.0
# Successfully installed google-api-python-client-2.84.0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
DataFolder = "/content/drive/MyDrive/SDAAI/Capstone-Project"

# %%
pip install ultralyticsplus
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting ultralyticsplus
#   Downloading ultralyticsplus-0.0.28-py3-none-any.whl (11 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from ultralyticsplus) (1.4.4)
# Collecting sahi<0.12.0,>=0.11.11
#   Downloading sahi-0.11.13-py3-none-any.whl (100 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.0/101.0 KB 7.3 MB/s eta 0:00:00
# Collecting fire
#   Downloading fire-0.5.0.tar.gz (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.3/88.3 KB 12.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting ultralytics<8.0.44,>=8.0.43
#   Downloading ultralytics-8.0.43-py3-none-any.whl (299 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 299.6/299.6 KB 24.9 MB/s eta 0:00:00
# Collecting huggingface-hub>=0.12.0
#   Downloading huggingface_hub-0.13.4-py3-none-any.whl (200 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.1/200.1 KB 10.4 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.12.0->ultralyticsplus) (23.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.12.0->ultralyticsplus) (6.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.12.0->ultralyticsplus) (4.65.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.12.0->ultralyticsplus) (4.5.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.12.0->ultralyticsplus) (2.27.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.12.0->ultralyticsplus) (3.10.7)
# Requirement already satisfied: pillow>=8.2.0 in /usr/local/lib/python3.9/dist-packages (from sahi<0.12.0,>=0.11.11->ultralyticsplus) (8.4.0)
# Collecting terminaltables
#   Downloading terminaltables-3.1.10-py2.py3-none-any.whl (15 kB)
# Collecting pybboxes==0.1.6
#   Downloading pybboxes-0.1.6-py3-none-any.whl (24 kB)
# Collecting click==8.0.4
#   Downloading click-8.0.4-py3-none-any.whl (97 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.5/97.5 KB 10.3 MB/s eta 0:00:00
# Requirement already satisfied: shapely>=1.8.0 in /usr/local/lib/python3.9/dist-packages (from sahi<0.12.0,>=0.11.11->ultralyticsplus) (2.0.1)
# Requirement already satisfied: opencv-python>=4.2.0.32 in /usr/local/lib/python3.9/dist-packages (from sahi<0.12.0,>=0.11.11->ultralyticsplus) (4.7.0.72)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from pybboxes==0.1.6->sahi<0.12.0,>=0.11.11->ultralyticsplus) (1.22.4)
# Requirement already satisfied: wheel>=0.38.0 in /usr/local/lib/python3.9/dist-packages (from ultralytics<8.0.44,>=8.0.43->ultralyticsplus) (0.40.0)
# Collecting sentry-sdk
#   Downloading sentry_sdk-1.19.1-py2.py3-none-any.whl (199 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.2/199.2 KB 19.4 MB/s eta 0:00:00
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.9/dist-packages (from ultralytics<8.0.44,>=8.0.43->ultralyticsplus) (1.10.1)
# Collecting thop>=0.1.1
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Requirement already satisfied: tensorboard>=2.4.1 in /usr/local/lib/python3.9/dist-packages (from ultralytics<8.0.44,>=8.0.43->ultralyticsplus) (2.12.1)
# Requirement already satisfied: torchvision>=0.8.1 in /usr/local/lib/python3.9/dist-packages (from ultralytics<8.0.44,>=8.0.43->ultralyticsplus) (0.15.1+cu118)
# Requirement already satisfied: psutil in /usr/local/lib/python3.9/dist-packages (from ultralytics<8.0.44,>=8.0.43->ultralyticsplus) (5.9.4)
# Requirement already satisfied: torch>=1.7.0 in /usr/local/lib/python3.9/dist-packages (from ultralytics<8.0.44,>=8.0.43->ultralyticsplus) (2.0.0+cu118)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.9/dist-packages (from ultralytics<8.0.44,>=8.0.43->ultralyticsplus) (0.12.2)
# Requirement already satisfied: matplotlib>=3.2.2 in /usr/local/lib/python3.9/dist-packages (from ultralytics<8.0.44,>=8.0.43->ultralyticsplus) (3.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas->ultralyticsplus) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas->ultralyticsplus) (2022.7.1)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from fire->ultralyticsplus) (1.16.0)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.9/dist-packages (from fire->ultralyticsplus) (2.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.2.2->ultralytics<8.0.44,>=8.0.43->ultralyticsplus) (3.0.9)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.2.2->ultralytics<8.0.44,>=8.0.43->ultralyticsplus) (1.0.7)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.2.2->ultralytics<8.0.44,>=8.0.43->ultralyticsplus) (5.12.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.2.2->ultralytics<8.0.44,>=8.0.43->ultralyticsplus) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.2.2->ultralytics<8.0.44,>=8.0.43->ultralyticsplus) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.2.2->ultralytics<8.0.44,>=8.0.43->ultralyticsplus) (1.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub>=0.12.0->ultralyticsplus) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub>=0.12.0->ultralyticsplus) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub>=0.12.0->ultralyticsplus) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub>=0.12.0->ultralyticsplus) (1.26.15)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=2.4.1->ultralytics<8.0.44,>=8.0.43->ultralyticsplus) (1.4.0)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=2.4.1->ultralytics<8.0.44,>=8.0.43->ultralyticsplus) (2.2.3)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=2.4.1->ultralytics<8.0.44,>=8.0.43->ultralyticsplus) (3.4.3)
# Requirement already satisfied: protobuf>=3.19.6 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=2.4.1->ultralytics<8.0.44,>=8.0.43->ultralyticsplus) (3.20.3)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=2.4.1->ultralytics<8.0.44,>=8.0.43->ultralyticsplus) (1.8.1)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=2.4.1->ultralytics<8.0.44,>=8.0.43->ultralyticsplus) (1.0.0)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=2.4.1->ultralytics<8.0.44,>=8.0.43->ultralyticsplus) (67.6.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=2.4.1->ultralytics<8.0.44,>=8.0.43->ultralyticsplus) (0.7.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=2.4.1->ultralytics<8.0.44,>=8.0.43->ultralyticsplus) (2.17.1)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=2.4.1->ultralytics<8.0.44,>=8.0.43->ultralyticsplus) (1.53.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from torch>=1.7.0->ultralytics<8.0.44,>=8.0.43->ultralyticsplus) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.9/dist-packages (from torch>=1.7.0->ultralytics<8.0.44,>=8.0.43->ultralyticsplus) (2.0.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.9/dist-packages (from torch>=1.7.0->ultralytics<8.0.44,>=8.0.43->ultralyticsplus) (3.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.9/dist-packages (from torch>=1.7.0->ultralytics<8.0.44,>=8.0.43->ultralyticsplus) (1.11.1)
# Requirement already satisfied: lit in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch>=1.7.0->ultralytics<8.0.44,>=8.0.43->ultralyticsplus) (16.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch>=1.7.0->ultralytics<8.0.44,>=8.0.43->ultralyticsplus) (3.25.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.4.1->ultralytics<8.0.44,>=8.0.43->ultralyticsplus) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.4.1->ultralytics<8.0.44,>=8.0.43->ultralyticsplus) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.4.1->ultralytics<8.0.44,>=8.0.43->ultralyticsplus) (5.3.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard>=2.4.1->ultralytics<8.0.44,>=8.0.43->ultralyticsplus) (1.3.1)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=3.2.0->matplotlib>=3.2.2->ultralytics<8.0.44,>=8.0.43->ultralyticsplus) (3.15.0)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.9/dist-packages (from markdown>=2.6.8->tensorboard>=2.4.1->ultralytics<8.0.44,>=8.0.43->ultralyticsplus) (6.1.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.9/dist-packages (from werkzeug>=1.0.1->tensorboard>=2.4.1->ultralytics<8.0.44,>=8.0.43->ultralyticsplus) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.9/dist-packages (from sympy->torch>=1.7.0->ultralytics<8.0.44,>=8.0.43->ultralyticsplus) (1.3.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.9/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.4.1->ultralytics<8.0.44,>=8.0.43->ultralyticsplus) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.9/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard>=2.4.1->ultralytics<8.0.44,>=8.0.43->ultralyticsplus) (3.2.2)
# Building wheels for collected packages: fire
#   Building wheel for fire (setup.py) ... done
#   Created wheel for fire: filename=fire-0.5.0-py2.py3-none-any.whl size=116952 sha256=555452d33eaa9efd71088852bf63a97446836dfde9f73dd651efe98bb4d28513
#   Stored in directory: /root/.cache/pip/wheels/f7/f1/89/b9ea2bf8f80ec027a88fef1d354b3816b4d3d29530988972f6
# Successfully built fire
# Installing collected packages: terminaltables, sentry-sdk, pybboxes, fire, click, sahi, huggingface-hub, thop, ultralytics, ultralyticsplus
#   Attempting uninstall: click
#     Found existing installation: click 8.1.3
#     Uninstalling click-8.1.3:
#       Successfully uninstalled click-8.1.3
# Successfully installed click-8.0.4 fire-0.5.0 huggingface-hub-0.13.4 pybboxes-0.1.6 sahi-0.11.13 sentry-sdk-1.19.1 terminaltables-3.1.10 thop-0.1.1.post2209072238 ultralytics-8.0.43 ultralyticsplus-0.0.28

# %%
import torch
import cv2
# Model
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')
# Out:
# /usr/local/lib/python3.9/dist-packages/torch/hub.py:286: UserWarning: You are about to download and run code from an untrusted repository. In a future release, this won't be allowed. To add the repository to your trusted list, change the command to {calling_fn}(..., trust_repo=False) and a command prompt will appear asking for an explicit confirmation of trust, or load(..., trust_repo=True), which will assume that the prompt is to be answered with 'yes'. You can also use load(..., trust_repo='check') which will only prompt for confirmation if the repo is not already trusted. This will eventually be the default behaviour
#   warnings.warn(
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to /root/.cache/torch/hub/master.zip
# requirements: YOLOv5 requirement "gitpython>=3.1.30" not found, attempting AutoUpdate...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting gitpython>=3.1.30
#   Downloading GitPython-3.1.31-py3-none-any.whl (184 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 KB 10.4 MB/s eta 0:00:00
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.10-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 KB 6.8 MB/s eta 0:00:00
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Installing collected packages: smmap, gitdb, gitpython
# Successfully installed gitdb-4.0.10 gitpython-3.1.31 smmap-5.0.0
#
# requirements: 1 package updated per /root/.cache/torch/hub/ultralytics_yolov5_master/requirements.txt
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# YOLOv5 🚀 2023-4-9 Python-3.9.16 torch-2.0.0+cu118 CPU
#
# Downloading https://github.com/ultralytics/yolov5/releases/download/v7.0/yolov5s.pt to yolov5s.pt...
# 100%|██████████| 14.1M/14.1M [00:00<00:00, 209MB/s]
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# Adding AutoShape...

# %%
#image_path = DataFolder+"/Safety Hat/Images/hard_hat_workers0.png" # or file, Path, PIL, OpenCV, numpy, list
image_path = DataFolder+"/Safety-Hat/Images/Helmet-Example01.jpg"

# Inference
results = model(image_path) 

# Results
results.print()  # or .show(), .save(), .crop(), .pandas(), etc.
# Out:
# image 1/1: 760x1095 1 person
# Speed: 29086.8ms pre-process, 266.6ms inference, 30.3ms NMS per image at shape (1, 3, 448, 640)

# %%
results.show()
print(results.pandas().xyxy[0])

for i in range(len(results.pandas().xyxy[0].name)):
    print("Object",i,results.pandas().xyxy[0].name[i])
# Out:
# <PIL.Image.Image image mode=RGB size=1095x760 at 0x7FC70BA6D4F0>
#         xmin        ymin       xmax   ymax  confidence  class    name
# 0  234.17659  162.732269  787.13678  760.0    0.826076      0  person
# Object 0 person

# %%
from ultralyticsplus import YOLO, render_result

# load model
model = YOLO('keremberke/yolov8m-hard-hat-detection')

# set model parameters
model.overrides['conf'] = 0.25  # NMS confidence threshold
model.overrides['iou'] = 0.45  # NMS IoU threshold
model.overrides['agnostic_nms'] = False  # NMS class-agnostic
model.overrides['max_det'] = 1000  # maximum number of detections per image

# set image
#image = 'https://github.com/RP-SDAAI/Capstone-Project/blob/72573878f2546c1c2984c3e1006ef8e7c72672ec/Helmet-Example01.jpg'

#image = 'https://github.com/ultralytics/yolov5/raw/master/data/images/zidane.jpg'

# perform inference
results = model.predict(image_path)

# observe results
print(results[0].boxes)
render = render_result(model=model, image=image_path, result=results[0])
render.show()
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/161 [00:00<?, ?B/s]
# Downloading best.pt:   0%|          | 0.00/52.0M [00:00<?, ?B/s]
# Ultralytics YOLOv8.0.43 🚀 Python-3.9.16 torch-2.0.0+cu118 CPU
# Model summary (fused): 218 layers, 25840918 parameters, 0 gradients, 78.7 GFLOPs
#
# image 1/1 /content/drive/MyDrive/SDAAI/Capstone-Project/Safety-Hat/Images/Helmet-Example01.jpg: 448x640 1 Hardhat, 1249.2ms
# Speed: 1.4ms preprocess, 1249.2ms inference, 10.3ms postprocess per image at shape (1, 3, 640, 640)
# tensor([[370.00000, 199.00000, 641.00000, 392.00000,   0.70751,   0.00000]])
# <PIL.Image.Image image mode=RGB size=1095x760 at 0x7FC7E8522A90>

# %% [markdown]
# ## Camera Capture
# ### Using a webcam to capture images for processing on the runtime.

# %%
from IPython.display import display, Javascript
from google.colab.output import eval_js
from base64 import b64decode

def take_photo(filename='photo.jpg', quality=0.8):
  js = Javascript('''
    async function takePhoto(quality) {
      const div = document.createElement('div');
      const capture = document.createElement('button');
      capture.textContent = 'Capture';
      div.appendChild(capture);

      const video = document.createElement('video');
      video.style.display = 'block';
      const stream = await navigator.mediaDevices.getUserMedia({video: true});

      document.body.appendChild(div);
      div.appendChild(video);
      video.srcObject = stream;
      await video.play();

      // Resize the output to fit the video element.
      google.colab.output.setIframeHeight(document.documentElement.scrollHeight, true);

      // Wait for Capture to be clicked.
      await new Promise((resolve) => capture.onclick = resolve);

      const canvas = document.createElement('canvas');
      canvas.width = video.videoWidth;
      canvas.height = video.videoHeight;
      canvas.getContext('2d').drawImage(video, 0, 0);
      stream.getVideoTracks()[0].stop();
      div.remove();
      return canvas.toDataURL('image/jpeg', quality);
    }
    ''')
  display(js)
  data = eval_js('takePhoto({})'.format(quality))
  binary = b64decode(data.split(',')[1])
  with open(filename, 'wb') as f:
    f.write(binary)
  return filename

# %%
from IPython.display import Image
try:
  filename = take_photo()
  print('Saved to {}'.format(filename))
  
  # Show the image which was just taken.
  display(Image(filename))
except Exception as err:
  # Errors will be thrown if the user does not have a webcam or if they do not
  # grant the page permission to access it.
  print(str(err))
# Out:
# Saved to photo.jpg

# %%
from ultralyticsplus import YOLO, render_result

def safety_helmet():

    # load model
    model = YOLO('keremberke/yolov8m-hard-hat-detection')

    # set model parameters
    model.overrides['conf'] = 0.25  # NMS confidence threshold
    model.overrides['iou'] = 0.45  # NMS IoU threshold
    model.overrides['agnostic_nms'] = False  # NMS class-agnostic
    model.overrides['max_det'] = 1000  # maximum number of detections per image

# set image
#image = 'https://github.com/RP-SDAAI/Capstone-Project/blob/72573878f2546c1c2984c3e1006ef8e7c72672ec/Helmet-Example01.jpg'

#image = 'https://github.com/ultralytics/yolov5/raw/master/data/images/zidane.jpg'

# perform inference
#results = model.predict(image_path)
    results = model.predict(filename)

#    self.assertEqual(array.shape, (1, 224, 224, 3))

# observe results
    print(results[0].boxes)
    render = render_result(model=model, image=filename, result=results[0])
    render.show()


safety_helmet()


## deploy in actual scenario, i need a device to run the code. (e.g. raspberry pi, nano jetson. laptop)
## run python (*.py) locally for streaming video
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-ff50b65b165c> in <cell line: 31>()
#      29
#      30
# ---> 31 safety_helmet()
#      32
#      33
#
# <ipython-input-4-ff50b65b165c> in safety_helmet()
#      19 # perform inference
#      20 #results = model.predict(image_path)
# ---> 21     results = model.predict(filename)
#      22
#      23 #    self.assertEqual(array.shape, (1, 224, 224, 3))
#
# NameError: name 'filename' is not defined

# %%
from ultralyticsplus import YOLO, render_result

def safety_helmet01(frame):

    # load model
    model = YOLO('keremberke/yolov8m-hard-hat-detection')

    # set model parameters
    model.overrides['conf'] = 0.25  # NMS confidence threshold
    model.overrides['iou'] = 0.45  # NMS IoU threshold
    model.overrides['agnostic_nms'] = False  # NMS class-agnostic
    model.overrides['max_det'] = 1000  # maximum number of detections per image

# set image
#image = 'https://github.com/RP-SDAAI/Capstone-Project/blob/72573878f2546c1c2984c3e1006ef8e7c72672ec/Helmet-Example01.jpg'

#image = 'https://github.com/ultralytics/yolov5/raw/master/data/images/zidane.jpg'

# perform inference
#results = model.predict(image_path)
    results = model.predict(frame)

#    self.assertEqual(array.shape, (1, 224, 224, 3))

# observe results
    print(results[0].boxes)
    render = render_result(model=model, image=frame, result=results[0])
    #render.show()
    return render


#safety_helmet()


## deploy in actual scenario, i need a device to run the code. (e.g. raspberry pi, nano jetson. laptop)
## run python (*.py) locally for streaming video

# %% [markdown]
# #Need help to get working code for streaming video on google colab
#
# Need to run streaming in local hardware e.g. jupyter notebook

# %%
#import cv2

#vid = cv2.VideoCapture(0) # For streaming links (#0 : Computer Webcam. Otherwise need to know the RTSP Url of the Webcam, or the IP address that connect directly to the CCTV)
#while True:
#    rdy,frame = vid.read()
#    print(rdy)
#    try:
    ##process frame to infer the model
#        processframe = safety_helmet01(frame)
    
#        cv2.imshow('Video Live IP cam', processframe)
        
#        key = cv2.waitKey(1) & 0xFF
#        if key ==ord('q'):
#            break
#    except:
#        pass

#vid.release()
#cv2.destroyAllWindows()
# Out:
# False
# Ultralytics YOLOv8.0.43 🚀 Python-3.9.16 torch-2.0.0+cu118 CPU
# Model summary (fused): 218 layers, 25840918 parameters, 0 gradients, 78.7 GFLOPs
# False
# Ultralytics YOLOv8.0.43 🚀 Python-3.9.16 torch-2.0.0+cu118 CPU
# Model summary (fused): 218 layers, 25840918 parameters, 0 gradients, 78.7 GFLOPs
# False
# Ultralytics YOLOv8.0.43 🚀 Python-3.9.16 torch-2.0.0+cu118 CPU
# Model summary (fused): 218 layers, 25840918 parameters, 0 gradients, 78.7 GFLOPs
# False
# Ultralytics YOLOv8.0.43 🚀 Python-3.9.16 torch-2.0.0+cu118 CPU
# Model summary (fused): 218 layers, 25840918 parameters, 0 gradients, 78.7 GFLOPs
# False
# Ultralytics YOLOv8.0.43 🚀 Python-3.9.16 torch-2.0.0+cu118 CPU
# Model summary (fused): 218 layers, 25840918 parameters, 0 gradients, 78.7 GFLOPs
# False
# Ultralytics YOLOv8.0.43 🚀 Python-3.9.16 torch-2.0.0+cu118 CPU
# Model summary (fused): 218 layers, 25840918 parameters, 0 gradients, 78.7 GFLOPs
# False
# Ultralytics YOLOv8.0.43 🚀 Python-3.9.16 torch-2.0.0+cu118 CPU
# Model summary (fused): 218 layers, 25840918 parameters, 0 gradients, 78.7 GFLOPs
# False
# Ultralytics YOLOv8.0.43 🚀 Python-3.9.16 torch-2.0.0+cu118 CPU
# Model summary (fused): 218 layers, 25840918 parameters, 0 gradients, 78.7 GFLOPs
# False
# Ultralytics YOLOv8.0.43 🚀 Python-3.9.16 torch-2.0.0+cu118 CPU
# Model summary (fused): 218 layers, 25840918 parameters, 0 gradients, 78.7 GFLOPs
# False
# Ultralytics YOLOv8.0.43 🚀 Python-3.9.16 torch-2.0.0+cu118 CPU
# Model summary (fused): 218 layers, 25840918 parameters, 0 gradients, 78.7 GFLOPs
# False
# Ultralytics YOLOv8.0.43 🚀 Python-3.9.16 torch-2.0.0+cu118 CPU
# Model summary (fused): 218 layers, 25840918 parameters, 0 gradients, 78.7 GFLOPs
# False
# Ultralytics YOLOv8.0.43 🚀 Python-3.9.16 torch-2.0.0+cu118 CPU
# Model summary (fused): 218 layers, 25840918 parameters, 0 gradients, 78.7 GFLOPs
# False
# Ultralytics YOLOv8.0.43 🚀 Python-3.9.16 torch-2.0.0+cu118 CPU
# Model summary (fused): 218 layers, 25840918 parameters, 0 gradients, 78.7 GFLOPs
# False
# Ultralytics YOLOv8.0.43 🚀 Python-3.9.16 torch-2.0.0+cu118 CPU
# Model summary (fused): 218 layers, 25840918 parameters, 0 gradients, 78.7 GFLOPs
# False
# Ultralytics YOLOv8.0.43 🚀 Python-3.9.16 torch-2.0.0+cu118 CPU
# Model summary (fused): 218 layers, 25840918 parameters, 0 gradients, 78.7 GFLOPs
# False
# Ultralytics YOLOv8.0.43 🚀 Python-3.9.16 torch-2.0.0+cu118 CPU
# Model summary (fused): 218 layers, 25840918 parameters, 0 gradients, 78.7 GFLOPs
# False
# Ultralytics YOLOv8.0.43 🚀 Python-3.9.16 torch-2.0.0+cu118 CPU
# Model summary (fused): 218 layers, 25840918 parameters, 0 gradients, 78.7 GFLOPs
# False
# Ultralytics YOLOv8.0.43 🚀 Python-3.9.16 torch-2.0.0+cu118 CPU
# Model summary (fused): 218 layers, 25840918 parameters, 0 gradients, 78.7 GFLOPs
# False
# Ultralytics YOLOv8.0.43 🚀 Python-3.9.16 torch-2.0.0+cu118 CPU
# Model summary (fused): 218 layers, 25840918 parameters, 0 gradients, 78.7 GFLOPs
# False
# Ultralytics YOLOv8.0.43 🚀 Python-3.9.16 torch-2.0.0+cu118 CPU
# Model summary (fused): 218 layers, 25840918 parameters, 0 gradients, 78.7 GFLOPs
# False
# Ultralytics YOLOv8.0.43 🚀 Python-3.9.16 torch-2.0.0+cu118 CPU
# False
# Ultralytics YOLOv8.0.43 🚀 Python-3.9.16 torch-2.0.0+cu118 CPU
# Model summary (fused): 218 layers, 25840918 parameters, 0 gradients, 78.7 GFLOPs
# False
# Ultralytics YOLOv8.0.43 🚀 Python-3.9.16 torch-2.0.0+cu118 CPU
# Model summary (fused): 218 layers, 25840918 parameters, 0 gradients, 78.7 GFLOPs
# False
# Ultralytics YOLOv8.0.43 🚀 Python-3.9.16 torch-2.0.0+cu118 CPU
# False
# False
# Ultralytics YOLOv8.0.43 🚀 Python-3.9.16 torch-2.0.0+cu118 CPU
# Model summary (fused): 218 layers, 25840918 parameters, 0 gradients, 78.7 GFLOPs
# False
# False
# Ultralytics YOLOv8.0.43 🚀 Python-3.9.16 torch-2.0.0+cu118 CPU
# Model summary (fused): 218 layers, 25840918 parameters, 0 gradients, 78.7 GFLOPs

# %% [markdown]
# #Install Gradio for model deployment
# #### Reference: https://github.com/gradio-app/gradio

# %%
# !pip install gradio
import gradio as gr
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting gradio
#   Downloading gradio-3.24.1-py3-none-any.whl (15.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.7/15.7 MB 88.8 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from gradio) (1.4.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from gradio) (1.22.4)
# Collecting ffmpy
#   Downloading ffmpy-0.3.0.tar.gz (4.8 kB)
#   Preparing metadata (setup.py) ... done
# Collecting orjson
#   Downloading orjson-3.8.9-cp39-cp39-manylinux_2_28_x86_64.whl (144 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.1/144.1 KB 17.6 MB/s eta 0:00:00
# Requirement already satisfied: altair>=4.2.0 in /usr/local/lib/python3.9/dist-packages (from gradio) (4.2.2)
# Collecting aiofiles
#   Downloading aiofiles-23.1.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.9/dist-packages (from gradio) (1.10.7)
# Collecting python-multipart
#   Downloading python_multipart-0.0.6-py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 KB 5.6 MB/s eta 0:00:00
# Collecting uvicorn
#   Downloading uvicorn-0.21.1-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.8/57.8 KB 6.6 MB/s eta 0:00:00
# Collecting httpx
#   Downloading httpx-0.23.3-py3-none-any.whl (71 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.5/71.5 KB 8.4 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from gradio) (2.27.1)
# Requirement already satisfied: pillow in /usr/local/lib/python3.9/dist-packages (from gradio) (8.4.0)
# Requirement already satisfied: markdown-it-py[linkify]>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from gradio) (2.2.0)
# Collecting fastapi
#   Downloading fastapi-0.95.0-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.1/57.1 KB 6.8 MB/s eta 0:00:00
# Collecting mdit-py-plugins<=0.3.3
#   Downloading mdit_py_plugins-0.3.3-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.5/50.5 KB 4.7 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from gradio) (4.5.0)
# Collecting websockets>=10.0
#   Downloading websockets-11.0.1-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (129 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.5/129.5 KB 9.2 MB/s eta 0:00:00
# Collecting gradio-client>=0.0.5
#   Downloading gradio_client-0.0.8-py3-none-any.whl (20 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.9/dist-packages (from gradio) (3.7.1)
# Requirement already satisfied: markupsafe in /usr/local/lib/python3.9/dist-packages (from gradio) (2.1.2)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.9/dist-packages (from gradio) (6.0)
# Collecting semantic-version
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Collecting aiohttp
#   Downloading aiohttp-3.8.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 46.8 MB/s eta 0:00:00
# Requirement already satisfied: huggingface-hub>=0.13.0 in /usr/local/lib/python3.9/dist-packages (from gradio) (0.13.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from gradio) (3.1.2)
# Collecting pydub
#   Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Requirement already satisfied: toolz in /usr/local/lib/python3.9/dist-packages (from altair>=4.2.0->gradio) (0.12.0)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.9/dist-packages (from altair>=4.2.0->gradio) (0.4)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.9/dist-packages (from altair>=4.2.0->gradio) (4.3.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.9/dist-packages (from gradio-client>=0.0.5->gradio) (2023.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from gradio-client>=0.0.5->gradio) (23.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.13.0->gradio) (4.65.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.13.0->gradio) (3.10.7)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.9/dist-packages (from markdown-it-py[linkify]>=2.0.0->gradio) (0.1.2)
# Collecting linkify-it-py<3,>=1
#   Downloading linkify_it_py-2.0.0-py3-none-any.whl (19 kB)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas->gradio) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas->gradio) (2.8.2)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->gradio) (2.0.12)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.3-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (158 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.8/158.8 KB 18.4 MB/s eta 0:00:00
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 KB 13.3 MB/s eta 0:00:00
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->gradio) (22.2.0)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.8.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (264 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.6/264.6 KB 23.0 MB/s eta 0:00:00
# Collecting starlette<0.27.0,>=0.26.1
#   Downloading starlette-0.26.1-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.9/66.9 KB 7.5 MB/s eta 0:00:00
# Requirement already satisfied: sniffio in /usr/local/lib/python3.9/dist-packages (from httpx->gradio) (1.3.0)
# Collecting httpcore<0.17.0,>=0.15.0
#   Downloading httpcore-0.16.3-py3-none-any.whl (69 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.6/69.6 KB 5.6 MB/s eta 0:00:00
# Collecting rfc3986[idna2008]<2,>=1.3
#   Downloading rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.9/dist-packages (from httpx->gradio) (2022.12.7)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->gradio) (1.0.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->gradio) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->gradio) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib->gradio) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->gradio) (4.39.3)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->gradio) (5.12.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->gradio) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->gradio) (1.26.15)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.9/dist-packages (from uvicorn->gradio) (8.0.4)
# Collecting h11>=0.8
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 KB 6.4 MB/s eta 0:00:00
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.9/dist-packages (from httpcore<0.17.0,>=0.15.0->httpx->gradio) (3.6.2)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=3.2.0->matplotlib->gradio) (3.15.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.9/dist-packages (from jsonschema>=3.0->altair>=4.2.0->gradio) (0.19.3)
# Collecting uc-micro-py
#   Downloading uc_micro_py-1.0.1-py3-none-any.whl (6.2 kB)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.8.1->pandas->gradio) (1.16.0)
# Building wheels for collected packages: ffmpy
#   Building wheel for ffmpy (setup.py) ... done
#   Created wheel for ffmpy: filename=ffmpy-0.3.0-py3-none-any.whl size=4707 sha256=2aaebc336404cd190d685585868dca4d8365d5cf228b6f2f5c389d2fb0feca5b
#   Stored in directory: /root/.cache/pip/wheels/91/e2/96/f676aa08bfd789328c6576cd0f1fde4a3d686703bb0c247697
# Successfully built ffmpy
# Installing collected packages: rfc3986, pydub, ffmpy, websockets, uc-micro-py, semantic-version, python-multipart, orjson, multidict, h11, frozenlist, async-timeout, aiofiles, yarl, uvicorn, starlette, mdit-py-plugins, linkify-it-py, httpcore, aiosignal, httpx, gradio-client, fastapi, aiohttp, gradio
# Successfully installed aiofiles-23.1.0 aiohttp-3.8.4 aiosignal-1.3.1 async-timeout-4.0.2 fastapi-0.95.0 ffmpy-0.3.0 frozenlist-1.3.3 gradio-3.24.1 gradio-client-0.0.8 h11-0.14.0 httpcore-0.16.3 httpx-0.23.3 linkify-it-py-2.0.0 mdit-py-plugins-0.3.3 multidict-6.0.4 orjson-3.8.9 pydub-0.25.1 python-multipart-0.0.6 rfc3986-1.5.0 semantic-version-2.10.0 starlette-0.26.1 uc-micro-py-1.0.1 uvicorn-0.21.1 websockets-11.0.1 yarl-1.8.2

# %%
import gradio as gr  ###running streaming video on gradio will incur charge)

#def test_preprocessing(self):
#        inp = inputs.Webcam(0)
#        array = inp.preprocess(BASE64_IMG)
#        self.assertEqual(array.shape, (1, 224, 224, 3))


##Check with lecturer on the following code ####

#demo = gr.Interface(fn=safety_helmet, inputs="image", outputs="image")

demo = gr.Interface(fn=safety_helmet, inputs=take_photo(), outputs=safety_helmet(), description="Safety Helmet Detection")

demo.launch(share=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-5ebcf9edd122> in <cell line: 13>()
#      11 #demo = gr.Interface(fn=safety_helmet, inputs="image", outputs="image")
#      12
# ---> 13 demo = gr.Interface(fn=safety_helmet, inputs=take_photo(), outputs=safety_helmet(), description="Safety Helmet Detection")
#      14
#      15 demo.launch(share=True)
#
# NameError: name 'safety_helmet' is not defined

# %%
##Sample Gradio code 
#import gradio as gr

#def greet(name):
#    return "Hello " + name + "!"

#demo = gr.Interface(fn=greet, inputs="text", outputs="text")

#fn: the function to wrap a UI around
#inputs: which component(s) to use for the input (e.g. "text", "image" or "audio")
#outputs: which component(s) to use for the output (e.g. "text", "image" or "label")


#demo.launch(share=True)
